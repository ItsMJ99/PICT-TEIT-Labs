# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest
from sklearn import metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Practical Exam Datasets/Regression/1.01. Simple linear regression.csv')

# %%
df.shape
# Out:
# (84, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SAT     84 non-null     int64
#  1   GPA     84 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.4 KB

# %%
df.isnull()
# Out:
#       SAT    GPA
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# ..    ...    ...
# 79  False  False
# 80  False  False
# 81  False  False
# 82  False  False
# 83  False  False
#
# [84 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# SAT    0
# GPA    0
# dtype: int64

# %%
df.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
X=df[['SAT']]
Y=df[['GPA']]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.7,random_state=10)

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
accuracy=model.score(X_test,Y_test)
coefficient=model.coef_
mse=metrics.mean_squared_error(Y_test,Y_pred)
msa=metrics.mean_absolute_error(Y_test,Y_pred)
rss=((Y_pred-Y_test)**2).sum()
r2_score=metrics.r2_score(Y_test,Y_pred)

# %%
print(f'Accuracy : {accuracy}')
print(f'Coefficient : {coefficient}')
print(f'Mean Square Error : {mse}')
print(f'Mean Absolute Error : {msa}')
print(f'Residual Sum of Squares : {rss}')
print(f'R2 Score : {r2_score}')
# Out:
# Accuracy : 0.4010417039566351
# Coefficient : [[0.00155223]]
# Mean Square Error : 0.04666948365756588
# Mean Absolute Error : 0.16243203568645465
# Residual Sum of Squares : GPA    1.213407
# dtype: float64
# R2 Score : 0.4010417039566351

# %%
plt.figure(figsize=(10,7))
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_test,Y_pred,color='blue')
plt.xlabel('SAT')
plt.ylabel('GPA')
plt.title('SAT vs GPA')
plt.show()

# %%
IFmodel=IsolationForest()

# %%
IFmodel.fit(df)
# Out:
# IsolationForest()

# %%
outlier=IFmodel.predict(df)
cleaned_data=df[outlier==1]

# %%
X=df[['SAT']]
Y=df[['GPA']]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8)

# %%
model2=LinearRegression()

# %%
model2.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model2.predict(X_test)

# %%
accuracy=model2.score(X_test,Y_test)
coefficient=model2.coef_
mse=metrics.mean_squared_error(Y_test,Y_pred)
msa=metrics.mean_absolute_error(Y_test,Y_pred)
rss=((Y_pred-Y_test)**2).sum()
r2_score=metrics.r2_score(Y_test,Y_pred)

# %%
print(f'Accuracy : {accuracy}')
print(f'Coefficient : {coefficient}')
print(f'Mean Square Error : {mse}')
print(f'Mean Absolute Error : {msa}')
print(f'Residual Sum of Squares : {rss}')
print(f'R2 Score : {r2_score}')
# Out:
# Accuracy : 0.5728736982237652
# Coefficient : [[0.00163084]]
# Mean Square Error : 0.029901205837425858
# Mean Absolute Error : 0.13970393399794423
# Residual Sum of Squares : GPA    0.50832
# dtype: float64
# R2 Score : 0.5728736982237652

# %%
plt.figure(figsize=(10,7))
plt.scatter(X,Y,color='red')
plt.plot(X_test,Y_pred,color='blue')
plt.xlabel('SAT')
plt.ylabel('GPA')
plt.title('SAT vs GPA')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(cleaned_data[['SAT']],cleaned_data[['GPA']],color='red')
plt.xlabel('SAT')
plt.ylabel('GPA')
plt.title('SAT vs GPA')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(df[['SAT']],df['GPA'],color='red')
plt.xlabel('SAT')
plt.ylabel('GPA')
plt.title('SAT vs GPA')
plt.show()
