# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing all required libraries
import numpy as np
import pandas as pd

# %%
#stores the data of Heart.csv into data variable in a tabular format
heart=pd.read_csv("Datasets/Heart.csv")

# %%
heart
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 1        1      1.5      2  3.0      normal  Yes
# 2        1      2.6      2  2.0  reversable  Yes
# 3        0      3.5      3  0.0      normal   No
# 4        0      1.4      1  0.0      normal   No
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No
#
# [303 rows x 15 columns]

# %%
#number of rows x columns
heart.shape
# Out:
# (303, 15)

# %%
#checks is value is null or not, False = Not Null AND True = NULL
heart.isna()
# Out:
#      Unnamed: 0    Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  \
# 0         False  False  False      False   False  False  False    False
# 1         False  False  False      False   False  False  False    False
# 2         False  False  False      False   False  False  False    False
# 3         False  False  False      False   False  False  False    False
# 4         False  False  False      False   False  False  False    False
# ..          ...    ...    ...        ...     ...    ...    ...      ...
# 298       False  False  False      False   False  False  False    False
# 299       False  False  False      False   False  False  False    False
# 300       False  False  False      False   False  False  False    False
# 301       False  False  False      False   False  False  False    False
# 302       False  False  False      False   False  False  False    False
#
#      MaxHR  ExAng  Oldpeak  Slope     Ca   Thal    AHD
# 0    False  False    False  False  False  False  False
# 1    False  False    False  False  False  False  False
# 2    False  False    False  False  False  False  False
# 3    False  False    False  False  False  False  False
# 4    False  False    False  False  False  False  False
# ..     ...    ...      ...    ...    ...    ...    ...
# 298  False  False    False  False  False  False  False
# 299  False  False    False  False  False  False  False
# 300  False  False    False  False  False  False  False
# 301  False  False    False  False  False  False  False
# 302  False  False    False  False   True  False  False
#
# [303 rows x 15 columns]

# %%
#counts NULL values in each column
heart.isna().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
#total number of NULL values
heart.isna().sum().sum()
# Out:
# 6

# %%
#it shows various descriptive statistics for a DataFrame. count= number of non nulls in cols, mean, SD, min val of col,max val of col, 25% val, 50% val, 75% val.
heart.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000

# %%
#information of each column col no., col name, no of non null cols, datat types, etc
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
#shows data types of each cols
heart.dtypes
# Out:
# Unnamed: 0      int64
# Age             int64
# Sex             int64
# ChestPain      object
# RestBP          int64
# Chol            int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
#is used to count the number of occurrences of the value 0 in each column of the Pandas DataFrame named "heart."
#(heart == 0) creates a Boolean DataFrame where each element is True if the corresponding element in the original DataFrame "heart" is equal to 0 
#and False otherwise. 

#shows number of zeros in each Column
(heart==0).sum(axis=0) #value can be any for heart==val.
# Out:
# Unnamed: 0      0
# Age             0
# Sex            97
# ChestPain       0
# RestBP          0
# Chol            0
# Fbs           258
# RestECG       151
# MaxHR           0
# ExAng         204
# Oldpeak        99
# Slope           0
# Ca            176
# Thal            0
# AHD             0
# dtype: int64

# %%
#shows number of zeros in each ROW
(heart==0).sum(axis=1)
# Out:
# 0      2
# 1      1
# 2      1
# 3      4
# 4      4
#       ..
# 298    4
# 299    2
# 300    2
# 301    4
# 302    4
# Length: 303, dtype: int64

# %%
#finds std of Sex Column, can be used for count,mean,std,min,max
heart['Sex'].std()
# Out:
# 0.46729882777012993

# %%
#stores only specific columns in data variable
data=heart[["Age","Sex","ChestPain","RestBP","Chol"]]
data
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 0     63    1       typical     145   233
# 1     67    1  asymptomatic     160   286
# 2     67    1  asymptomatic     120   229
# 3     37    1    nonanginal     130   250
# 4     41    0    nontypical     130   204
# ..   ...  ...           ...     ...   ...
# 298   45    1       typical     110   264
# 299   68    1  asymptomatic     144   193
# 300   57    1  asymptomatic     130   131
# 301   57    0    nontypical     130   236
# 302   38    1    nonanginal     138   175
#
# [303 rows x 5 columns]

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.26.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\madhav\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
plt.scatter(data.Age,data.RestBP,label="RestBP")
plt.xlabel("Age")
plt.ylabel("RestBP")
plt.title("RestBP of People")
plt.legend()
plt.show()

# %%
plt.scatter(data.Age[data.Sex==1],data.Chol[data.Sex==1],color='green',label="Male")
plt.scatter(data.Age[data.Sex==0],data.Chol[data.Sex==0],color='orange',label="Female")
plt.xlabel("Age")
plt.ylabel("Chol")
plt.title("Cholestrol of people")
plt.legend(loc="upper left")
plt.show()

# %%
data1 = [heart.ChestPain[heart.ChestPain == 'typical'].count(),heart.ChestPain[heart.ChestPain == 'asymptomatic'].count()
,heart.ChestPain[heart.ChestPain == 'nonanginal'].count(),heart.ChestPain[heart.ChestPain == 'nonanginal'].count()]
label1 = ['typical', 'asymptomatic', 'nonanginal', 'nontypical']
plt.pie(data1,labels=label1);
plt.title("People with Chestpain")
plt.show()

# %%
plt.hist(heart.MaxHR,bins=20,color='Blue')
plt.title("Max HR")
plt.show()

# %%
var=np.array([[10,20,30],[29,19,9]])
print("Column min : ",var.min(axis=0))
print("Column max : ",var.max(axis=0))
print("Row min    : ",var.min(axis=1))
print("Row max    : ",var.max(axis=1))
# Out:
# Column min :  [10 19  9]
# Column max :  [29 20 30]
# Row min    :  [10  9]
# Row max    :  [30 29]

# %%
tp = 45  # true positives
tn = 395  # true negatives
fp = 55  # false positives
fn = 5   # false negatives

# Construct the confusion matrix
confusion_matrix = np.array([[tp, fn], [fp, tn]])

# Create a confusion matrix display
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[0, 1])

# Plot the confusion matrix
cm_display.plot(cmap='Greens')  # You can choose a colormap as per your preference
plt.title('Confusion Matrix')
plt.show()

# %%
accuracy = ( tp + tn )/( tp + tn + fp + fn)
precision = tp / ( tp + fp)
recall = tp / ( tp + fn )
f1score= 2 * ( precision * recall )/( precision + recall )

print("Accuracy = ",accuracy)
print("Precision = ",precision)
print("Recall = ",recall)
print("F1 Score = ",f1score)
# Out:
# Accuracy =  0.88
# Precision =  0.45
# Recall =  0.9
# F1 Score =  0.6
